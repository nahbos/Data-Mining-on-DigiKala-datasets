# %% [markdown]
# ### Copyright (C) 2020 Sobhan Moradiyan Daghigh - All Rights Reserved
#
# ## Data Mining UniProj - no.4
# #### 1/6/2021

# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk import pos_tag
import matplotlib.pyplot as plt
import string

# %% [markdown]
# ### Reading the dataset

# %%
quality = pd.read_excel('dataset/keifiat.xlsx')

# %% [markdown]
# ### For this process we need just these 3 columns

# %%
dataset = quality.filter(['product_id', 'comment', 'recommend']).copy()
dataset.head()
# Out:
#    product_id                                            comment  \
# 0        3692                  واقعا عالیه. من که ازش خیلی راضیم
# 1       90213  سلام، قبل اینکه نظرم رو بگم میخواستم به یک موض...
# 2       59473  گیره های فلزی خیلی سخت تا میشوند و لذا حوله را...
# 3      120499  همه چیز در رابطه با ظاهر این گوشی بسیار خوب اس...
# 4       67200  اگر ظرفیتش براتون کافیه حتما بخرید.\r\nیه شارژ...
#
#          recommend
# 0               \N
# 1      recommended
# 2  not_recommended
# 3          no_idea
# 4          no_idea

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   product_id  100000 non-null  int64
#  1   comment     99883 non-null   object
#  2   recommend   100000 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 2.3+ MB

# %% [markdown]
# ### Drop the NaNs of recommend column

# %%
dataset = dataset[dataset['recommend'] != '\\N']
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63618 entries, 1 to 99999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  63618 non-null  int64
#  1   comment     63586 non-null  object
#  2   recommend   63618 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# ### And drop the NaNs of comment column

# %%
dataset.dropna(inplace=True)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 63586 entries, 1 to 99999
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   product_id  63586 non-null  int64
#  1   comment     63586 non-null  object
#  2   recommend   63586 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.9+ MB

# %% [markdown]
# ### Now we have a cleaned dataset
# ### Save it to a csv and translate the comments in "Translator.ipynb"

# %%
dataset.to_csv('preprocessed_dataset.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ### Ok, lemme explain u what I did with huge dataset in translation level
# ### To make a gr8 sub-dataset, I did a filter on dataset and tried to seperate products which have more than 50 comments
# ### Therefore, I made a gr8 dimension reduction :)

# %% [markdown]
# ### After that process, read the translated dataset

# %%
translated = pd.read_csv('translate_dataset.csv')
translated.head()
# Out:
#    product_id                                            comment    recommend  \
# 0      111178  در کل وسیله ای خوب و مورد نیاز است. اگر یک میل...  recommended
# 1      180451             تو خریدش شک نکنید،عالی و بسیار کاربردی  recommended
# 2      195191  فست شارژ داره که خیلی خوبه\r\nکیفیت بدنش عالیه...  recommended
# 3      195191  بیش از ۲ سال پیش از دیجی خریدم  با وجود ناراضی...  recommended
# 4      180451                 واقعا خیلی ازش راضی هستم\r\nبی نقص  recommended
#
#                                          eng_comment
# 0  Overall a good and needed tool. If a flat bar ...
# 1  Do not hesitate to buy it, excellent and very ...
# 2  It has a fast charge, which is very good  The ...
# 3  I bought it from Digi more than 2 years ago, d...
# 4      I am really very satisfied with it  flawless

# %%
translated.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1176 entries, 0 to 1175
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   product_id   1176 non-null   int64
#  1   comment      1176 non-null   object
#  2   recommend    1176 non-null   object
#  3   eng_comment  1176 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 36.9+ KB

# %% [markdown]
# ### The most important part of this implementation is here
# ### Try to make a process on text using nlp tools
# #### 1- Lowercase
# #### 2- Removing Punctuation
# #### 3- Word Tokenization
# #### 4- Stopword Filtering
# #### 5- Stemming

# %%
preprocessed_comments = []
for _, (recommend, comment) in translated.iloc[:, 2:4].iterrows():

    # Lowercase
    comment = comment.lower()
    
    # Removing Punctuation
    comment = "".join([char for char in comment if char not in string.punctuation])
    
    # Word Tokenization
    comment = word_tokenize(comment)
    
    # Stopword Filtering
    stop_words = stopwords.words('english')
    [stop_words.remove(x) for x in ['not', 'very']]
    comment = [word for word in comment if word not in stop_words]
    
    # Filter 
    comment = pos_tag(comment)
    comment = [word for word, tag in comment if tag in ('RB', 'JJ', 'JJR' )]
    
    # Stemming
    porter = PorterStemmer()
    comment = [porter.stem(word) for word in comment]
    comment = ' '.join(comment)
    
    # Impress the recommend
    comment += (' ' + recommend)
    
    preprocessed_comments.append(comment)

# %% [markdown]
# ### Represent each comment as a vector

# %%
vectorizer = TfidfVectorizer(stop_words={'english'})
X = vectorizer.fit_transform(preprocessed_comments)

# %% [markdown]
# ## K-means

# %% [markdown]
# ### First, we must decide on the number of clusters, I mean the value of k

# %% [markdown]
# ### To do this, I wanna make a visualization on a range of different k s

# %%
sum_of_squared_distances = []
K = range(1,20)

for k in K:
    km = KMeans(n_clusters=k, max_iter=50, n_init=100)
    km = km.fit(X)
    sum_of_squared_distances.append(km.inertia_)

plt.plot(K, sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ### According to the above plot, theres a dent on k=7

# %%
true_k = 7
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=50, n_init=100)
model.fit(X)
labels=model.labels_

translated['cluster'] = labels
translated
# Out:
#       product_id                                            comment  \
# 0         111178  در کل وسیله ای خوب و مورد نیاز است. اگر یک میل...
# 1         180451             تو خریدش شک نکنید،عالی و بسیار کاربردی
# 2         195191  فست شارژ داره که خیلی خوبه\r\nکیفیت بدنش عالیه...
# 3         195191  بیش از ۲ سال پیش از دیجی خریدم  با وجود ناراضی...
# 4         180451                 واقعا خیلی ازش راضی هستم\r\nبی نقص
# ...          ...                                                ...
# 1171      416458                                        در کل خوبه.
# 1172      416458  قسمت توری دارش باید لب توری کش داشته باشه که ش...
# 1173      319878  نسبت به قیمتش خوش ساخت و با کیفیت هست. نسبت به...
# 1174      416458  عالی من یک دو هفته ای میشه خریدم پیشنهاد میکنم...
# 1175      390726                    من تازه سفارش دادم ببنم چی میشه
#
#         recommend                                        eng_comment  cluster
# ...

# %% [markdown]
# ### K-means clusterd the dataset in 7 part
# ### Now try to make a lable for each cluster and decide to put a rate for each group

# %%
groups = translated.groupby(by=['cluster'])
groups.first()
# Out:
#          product_id                                            comment  \
# cluster
# 0            534138  خیلی خیلی بده من هم از همین دیجی کالا خریدم بع...
# 1            534138  خریدن این محصول مساوی با پول دور ریختن نه باتر...
# 2            180451                   من دومین بار که میخرم خیلی عالیه
# 3            180451  سلام من چند ماهه این ساعت رو خریدم  گجت خوبیه ...
# 4            180451             تو خریدش شک نکنید،عالی و بسیار کاربردی
# 5            180451                                           فقط عالی
# 6            111178  در کل وسیله ای خوب و مورد نیاز است. اگر یک میل...
#
#                recommend                                        eng_comment
# cluster
# 0                no_idea  Give it a lot, I also bought the product from ...
# 1        not_recommended  Buying this product equals throwing away money...
# 2            recommended                 The second time I buy it is great
# 3            recommended  Hi, I bought this watch a few months ago, I su...
# ...

# %%
for grp, pdf in groups:
    print("\n\nclustar:", grp, "\nvalues:\n", pd.DataFrame(pdf['recommend'].tolist()).value_counts())
# Out:
# clustar: 0
# values:
#  no_idea    135
# dtype: int64
#
#
# clustar: 1
# values:
#  not_recommended    143
# recommended         12
# no_idea              5
# dtype: int64
#
#
# clustar: 2
# values:
#  recommended        101
# not_recommended      1
# dtype: int64
#
#
# clustar: 3
# values:
#  recommended        115
# not_recommended      1
# no_idea              1
# dtype: int64
#
#
# clustar: 4
# values:
#  recommended    66
# dtype: int64
#
#
# clustar: 5
# values:
#  recommended    46
# dtype: int64
#
#
# clustar: 6
# values:
#  recommended        528
# no_idea             17
# not_recommended      5
# dtype: int64

# %% [markdown]
# ### F**K :) WE DID IT :)))

# %% [markdown]
# ### The dataset is clusterd very nice and its seems that each cluster have the right values

# %% [markdown]
# ### Now try to put a score or rate for each cluster

# %%
for grp, pdf in groups:
    print("\n\ncluster: ", grp, pd.DataFrame(pdf['comment'].tolist()).iloc[:10,])
# Out:
# cluster:  0                                                    0
# 0  خیلی خیلی بده من هم از همین دیجی کالا خریدم بع...
# 1  متاسفانه پشتیه خیلی ضعیفی داره من دوتا خریدم و...
# 2  یک ماه بعد ازینکه تحویل گرفتم چراغ‌های نشانگر ...
# 3  امروز به دستم رسید. فقط نمیدونم چراغ قوه ش چطو...
# 4  خیلی سنگینه خدایی نکرده موقع شارژ همزمان بخای ...
# 5  هیچ ایرادی نداره فقط نمی دونم چرا لپ‌تاپ‌رو شا...
# 6  فشار بیش ازحد به شارژر میاره که نمیشه دست بگیر...
# 7  کیف خوبیه،کوچیک و جم و جوره،فقد کیفت زیپش خیلی...
# 8  تازه به دستم رسیده و هنوز نسبت به کارآیی و عمل...
# 9  دوستان من این پاور رو خریدم شارژ اولیه اش چند ...
#
#
# cluster:  1                                                    0
# 0  خریدن این محصول مساوی با پول دور ریختن نه باتر...
# 1  چیزی که به دستت میرسه تو تصویر نیست!کاملا فرق ...
# 2  نمیدونم چرا ملت انقد از این محصول خریدن و به ب...
# 3  هیچ کدوم از مشکلایی رو که دوستان میگن نداره.من...
# 4  یکبار هم جواب نداد. میله پشتش خم شد از بس نرم ...
# ...

# %% [markdown]
# ### According to above clusters values, I decide to put these rates to each cluster
# #### 0: 2.5
# #### 1: 0.5
# #### 2: 5
# #### 3: 4
# #### 4: 5
# #### 5: 5
# #### 6: 4.5

# %%
cluster_rate = {0: 2.5, 1: 0.5, 2: 5, 3: 4, 4: 5, 5: 5, 6: 4.5}
translated['rate'] = translated['cluster'].apply(lambda x: next((v for k, v in cluster_rate.items() if x == k), 0))
translated
# Out:
#       product_id                                            comment  \
# 0         111178  در کل وسیله ای خوب و مورد نیاز است. اگر یک میل...
# 1         180451             تو خریدش شک نکنید،عالی و بسیار کاربردی
# 2         195191  فست شارژ داره که خیلی خوبه\r\nکیفیت بدنش عالیه...
# 3         195191  بیش از ۲ سال پیش از دیجی خریدم  با وجود ناراضی...
# 4         180451                 واقعا خیلی ازش راضی هستم\r\nبی نقص
# ...          ...                                                ...
# 1171      416458                                        در کل خوبه.
# 1172      416458  قسمت توری دارش باید لب توری کش داشته باشه که ش...
# 1173      319878  نسبت به قیمتش خوش ساخت و با کیفیت هست. نسبت به...
# 1174      416458  عالی من یک دو هفته ای میشه خریدم پیشنهاد میکنم...
# 1175      390726                    من تازه سفارش دادم ببنم چی میشه
#
#         recommend                                        eng_comment  cluster  \
# ...

# %% [markdown]
# ### Look how beautiful the comments and rates are matches :)

# %% [markdown]
# ### Hefff :)

# %% [markdown]
# ### Ok now try to calculate average rate of each product

# %%
groups = translated.groupby(by=['product_id', 'rate'])
groups.first()
# Out:
#                                                            comment  \
# product_id rate
# 111178     0.5   یکبار هم جواب نداد. میله پشتش خم شد از بس نرم ...
#            2.5   متاسفانه پشتیه خیلی ضعیفی داره من دوتا خریدم و...
#            4.0   تو تخفیف قبلی خریدم خیلی خوب هستش اشتباهی که ک...
#            4.5   در کل وسیله ای خوب و مورد نیاز است. اگر یک میل...
#            5.0   در صورت خرید در پیشنهاد ویژه بسیار عالیست مخصو...
# ...                                                            ...
# 700304     0.5   بدنه ای خش پذیر طی ی هفته استفاده کل بدنش خش ع...
#            2.5   امروز به دستم رسید. فقط نمیدونم چراغ قوه ش چطو...
#            4.0   در شگفت انگیز خریدم و نسبت به قیمت ارزش خرید ب...
#            4.5   اول تشکر بکنم از دیجی کالا که ۱۲ ساعته برام رس...
#            5.0                  عالیه قدرتش خیلی عالیه.۱۰۰۰۰ واقعی
#
#                        recommend  \
# product_id rate
# 111178     0.5   not_recommended
#            2.5           no_idea
# ...

# %%
for product in translated['product_id'].unique():
    product_rate = 0
    count = 0
    for grp, pdf in groups:
        if product == grp[0]:
            count += len(pdf)
            product_rate += np.multiply(grp[1], len(pdf))
            
    print("Product: ", product, "     Amount of sold: ", count, "     Avg rate: ", round(np.divide(product_rate,count), 2))
# Out:
# Product:  111178      Amount of sold:  122      Avg rate:  4.0
# Product:  180451      Amount of sold:  85      Avg rate:  4.07
# Product:  195191      Amount of sold:  66      Avg rate:  4.01
# Product:  319868      Amount of sold:  92      Avg rate:  3.95
# Product:  399474      Amount of sold:  52      Avg rate:  2.55
# Product:  534138      Amount of sold:  56      Avg rate:  2.76
# Product:  275197      Amount of sold:  57      Avg rate:  4.17
# Product:  390726      Amount of sold:  81      Avg rate:  2.73
# Product:  351601      Amount of sold:  71      Avg rate:  3.56
# Product:  130298      Amount of sold:  53      Avg rate:  4.01
# Product:  643764      Amount of sold:  64      Avg rate:  4.12
# Product:  416458      Amount of sold:  87      Avg rate:  3.52
# Product:  700304      Amount of sold:  169      Avg rate:  4.07
# Product:  319878      Amount of sold:  121      Avg rate:  4.13

# %% [markdown]
# ### Yohaaaa :)
